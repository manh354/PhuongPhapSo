# %%
# %run LeastSquare/leastSquare.py
# Out:
# ['cos(b1*x)', 'cos(b2*x)', 'cos(b3*x)', 'cos(b4*x)', 'cos(b5*x)', '-a1*x*sin(b1*x)', '-a2*x*sin(b2*x)', '-a3*x*sin(b3*x)', '-a4*x*sin(b4*x)', '-a5*x*sin(b5*x)']
# lần lặp thứ : 1
# [5.00960746 1.05083274 2.00574134 1.94053983 0.9986958  1.0043176
#  3.06611907 5.02397652 7.00360643 8.99060911]
# lần lặp thứ : 2
# a1 = 5.031534774961865; a2 = 3.3196468968453736; a3 = 2.938380532797397; a4 = 1.992043448093899; a5 = 0.9918702580755069; b1 = 1.0016466061279994; b2 = 2.8402583718601004; b3 = 4.990473346657587; b4 = 7.00060307866056; b5 = 8.99918123737173;
# lần lặp thứ : 3
# a1 = 4.828987844131637; a2 = 1.036118572804119; a3 = 2.879242193936837; a4 = 2.117441819350228; a5 = 1.0407727831790494; b1 = 0.9944716017900593; b2 = 2.9445882881107477; b3 = 4.990437233901675; b4 = 6.9975134521008435; b5 = 9.009511342466825;
# lần lặp thứ : 4
# ...
