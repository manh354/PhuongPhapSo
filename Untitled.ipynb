# %%
# %run LeastSquare/leastSquare.py
# Out:
# ['cos(x)', 'x', '1']
# lần lặp thứ : 1
# [5.29030335 0.49859748 1.83137152]
# lần lặp thứ : 2
# a = 5.2903033539312885; b = 0.4985974801047637; c = 1.8313715185999193;
