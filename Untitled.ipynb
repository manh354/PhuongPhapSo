# %%
# %run LeastSquare/leastSquare.py
# Out:
# ['cos(x)', 'x', '1']
# lần lặp thứ : 1
# a = 6.248685836179514; b = 1.5748784562153584; c = 0.3515458903201843;
# lần lặp thứ : 2
# a = 6.248685836180128; b = 1.5748784562157867; c = 0.3515458903195349;
